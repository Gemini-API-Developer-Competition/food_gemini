# %%
import google.generativeai as genai
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import google.generativeai as genai
#       2 import os
#
# File ~\anaconda3\Lib\site-packages\google\generativeai\__init__.py:45
#      41 from __future__ import annotations
#      43 from google.generativeai import version
# ---> 45 from google.generativeai import protos
#      46 from google.generativeai import types
#      47 from google.generativeai.types import GenerationConfig
#
# File ~\anaconda3\Lib\site-packages\google\generativeai\protos.py:74
#       1 # -*- coding: utf-8 -*-
#       2 # Copyright 2024 Google LLC
#       3 #
#    (...)
#      13 # See the License for the specific language governing permissions and
#      14 # limitations under the License.
#      15 """
#      16 This module provides low level access to the ProtoBuffer "Message" classes used by the API.
#      17
# ...
